# %% [markdown]
# # TakeMeter Colab Runner
#
# Use this notebook instead of the original starter notebook with TODO placeholders.
#
# Before running:
#
# 1. Runtime -> Change runtime type -> T4 GPU.
# 2. Open the Secrets panel and add `GROQ_API_KEY`.
# 3. Run all cells.
# 4. When prompted, upload your labeled CSV with `text` and `label` columns.
#
# Outputs will be written to `reports/evaluation_results.json`, `reports/predictions.csv`, `reports/wrong_predictions.csv`, `reports/sample_classifications.csv`, `reports/test_split.csv`, and `reports/confusion_matrix.png`.

# %%
# Replace this if you choose a different community.
COMMUNITY = "r/berkeley"

# %%
# Fetch the completed TakeMeter workflow from the submitted GitHub repo.
# !wget -q https://raw.githubusercontent.com/mthinhngn/TakeMeter/main/ai201_project3_takemeter_starter_clean.py -O takemeter_workflow.py
print("Downloaded takemeter_workflow.py")

# %%
# Run the workflow. You will be prompted to upload your labeled CSV.
# %run takemeter_workflow.py --community "$COMMUNITY"

# %%
# Download generated artifacts after the run finishes.
from google.colab import files

for path in [
    "reports/evaluation_results.json",
    "reports/predictions.csv",
    "reports/wrong_predictions.csv",
    "reports/sample_classifications.csv",
    "reports/test_split.csv",
    "reports/confusion_matrix.png",
]:
    files.download(path)
